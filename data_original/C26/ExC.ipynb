# %%
#CID:01730549
#1
def ReadFileStr(A):
    a=f.readlines()
    astrip=[]
    for i in a:
        astrip=astrip+[i.rstrip()] #removes \n in each line
    f.close()
    return(astrip)
f=open('CV19.txt','r')
f1=ReadFileStr(f)
#each 15 term is a week
#date going from odd to even and back to odd every week change
#number of infection going from even to odd and back to even every week change
#need to simplify the file
f2=[]
i=0
while(i<len(f1)):
    if i%15==0: #get rid of weeks in the file
        i=i+1
    f2=f2+[f1[i]]
    i=i+1
sum=0
for i in range(0,len(f2)):
    if i%2!=0:
        sum=sum+int(f2[i])
print('overall number of infections=',sum)

#2
avg=sum/13 #13 total weeks
print('weekly average=',avg)

#3
l=[] #initiate list
for i in range(0,len(f2)):
    if i%2!=0 and int(f2[i])>2000:
        l=l+[str(f2[i-1])]
print('list of days when number of infections>2000:')
for i in l:
    print(i)

#4
w=[]
w=w+[3+12+38+29+49+43+67]#1st week
s=0
for i in range(1,len(f2)):
    
    if i%2!=0:
        s=s+int(f2[i])
    if i%14==0:
        w=w+[s]
        s=0
    w=w+[s]
        
        
print(w)

#5
max=0
for i in range(0,len(w)):
        if(int(f2[i])>max):
            max=int(f2[i])
# Out:
# overall number of infections= 273319
# weekly average= 21024.53846153846
# list of days when number of infections>2000:
# 2020-03-27
# 2020-03-28
# 2020-03-29
# 2020-03-30
# 2020-03-31
# 2020-04-01
# 2020-04-02
# 2020-04-03
# 2020-04-04
# 2020-04-05
# 2020-04-06
# 2020-04-07
# 2020-04-08
# 2020-04-09
# 2020-04-10
# 2020-04-11
# 2020-04-12
# 2020-04-13
# 2020-04-14
# 2020-04-15
# 2020-04-16
# 2020-04-17
# 2020-04-18
# 2020-04-19
# 2020-04-20
# 2020-04-21
# 2020-04-22
# 2020-04-23
# 2020-04-24
# 2020-04-25
# 2020-04-26
# 2020-04-27
# 2020-04-28
# 2020-04-29
# 2020-04-30
# 2020-05-01
# 2020-05-02
# 2020-05-03
# 2020-05-04
# 2020-05-05
# 2020-05-06
# 2020-05-07
# 2020-05-08
# 2020-05-09
# 2020-05-10
# 2020-05-11
# 2020-05-12
# 2020-05-13
# 2020-05-14
# 2020-05-15
# 2020-05-16
# 2020-05-17
# 2020-05-18
# 2020-05-19
# 2020-05-20
# 2020-05-22
# 2020-05-23
# 2020-05-24
# 2020-05-25
# 2020-05-27
# 2020-05-28
# 2020-05-30
# [241, 3, 3, 15, 15, 53, 53, 82, 82, 131, 131, 174, 174, 241, 241, 0, 46, 46, 96, 96, 183, 183, 317, 317, 525, 525, 867, 867, 1118, 1118, 0, 152, 152, 559, 559, 1235, 1235, 1882, 1882, 2588, 2588, 3623, 3623, 3623, 3623, 0, 669, 669, 1636, 1636, 3063, 3063, 4515, 4515, 6644, 6644, 9529, 9529, 12075, 12075, 0, 2433, 2433, 5052, 5052, 8061, 8061, 12385, 12385, 16629, 16629, 21079, 21079, 24814, 24814, 0, 5903, 5903, 9705, 9705, 13339, 13339, 18830, 18830, 23174, 23174, 28369, 28369, 37088, 37088, 0, 5288, 5288, 9630, 9630, 14882, 14882, 19485, 19485, 24102, 24102, 29701, 29701, 35226, 35226, 0, 5850, 5850, 10526, 10526, 14827, 14827, 19278, 19278, 23861, 23861, 29247, 29247, 34160, 34160, 0, 4463, 4463, 8772, 8772, 12768, 12768, 16844, 16844, 22876, 22876, 29077, 29077, 33883, 33883, 0, 4339, 4339, 8324, 8324, 12730, 12730, 18941, 18941, 24455, 24455, 29104, 29104, 33000, 33000, 0, 3923, 3923, 7800, 7800, 11203, 11203, 14445, 14445, 17891, 17891, 21451, 21451, 24901, 24901, 0, 3534, 3534, 6245, 6245, 8657, 8657, 8657, 8657, 11272, 11272, 14559, 14559, 17518, 17518, 0, 2405, 2405, 4030, 4030, 8073, 8073, 10086, 10086, 11973, 11973, 14068, 14068, 15672]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-d5d5ac594b04> in <module>
#      59 max=0
#      60 for i in range(0,len(w)):
# ---> 61         if(int(f2[i])>max):
#      62             max=int(f2[i])
#      63
#
# ValueError: invalid literal for int() with base 10: '2020-03-02'
