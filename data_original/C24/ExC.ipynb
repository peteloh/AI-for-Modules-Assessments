# %%
# Solution for Task C
# My CID Number: 01366896

import math as mt

# open the file for reading
f = open('CV19.txt','r')
t = f.readlines() # save data initially into a temporary variable t
f.close() # close the file

# no of weeks N = 13
N = 13
RN = range(0,N)

# organise data in a list of tuples - import data from file into a list
CovidStats = [] # list of weeks - data type: list of tuples
c = 0
for i in RN:
    # Week #, Day #, Stat # - 7 days per week
    CovidStats += [( t[c].rstrip() , 
                    t[c+1].rstrip() , int(t[c+2].rstrip()) ,
                    t[c+3].rstrip() , int(t[c+4].rstrip()) , 
                    t[c+5].rstrip() , int(t[c+6].rstrip()) , 
                    t[c+7].rstrip() , int(t[c+8].rstrip()) ,
                    t[c+9].rstrip() , int(t[c+10].rstrip()) ,
                    t[c+11].rstrip() , int(t[c+12].rstrip()) ,
                    t[c+13].rstrip() , int(t[c+14].rstrip()) ,
                   )] 
    c += 15
#

# We have created a list of tuples!
#print(type(CovidStats))
#print(type(CovidStats[0]))
#for i in CovidStats:
#    print(i)

# Find the following:
# 1. The overall number of infections registered in the given period
# 2. The weekly number of infections per every week provided
# 3. The list of days when the number of infected people exceeded (>) 2000
# 4. The weekly percentage increment of infections (apart from week 1)
# 5. The week with the highest number of infections

# compute the weekly number of infections
WeekS = []
C = 0
for i in RN:
    Sum = 0
    for j in R2:
        WeekS += [Sum[i][c]] 
        print(S)
print("Overall Weekly Infections: " + str(S))

# compute the overall number of infections
# concept would be to sum up the number of weekly infections found earlier
S = 0 # initialise sum = 0
for i in RN:
    R2 = range(0,14,2)
    for j in R2:
        S += CovidStats[i][c] 
        print(S)
print("Overall Number of Infections: " + str(S))


# list of days when number of infected people (>) 2000

                ]
ListDays = []
C = 0
for i in RN:
    for j in R2:
        #this is the concept but I did not have time to implement it
        if Inf > 2000:
            ListDays += [Day
print("Overall Weekly Infections: " + str(S))

# Percentage increment
# W(n) is the number of infections in week n and W(n-1) is the number of infections in the previous week
PercentIncre = (W(n) - W(n-1) / W(n-1)) * 100

# Week with highest number of infections
MaxInf = 0
for i in RN:
    if Inf > MaxInf:
        MaxInf = Inf
print("Week with most infections: " + str(MaxInf))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-3852f44db4be> in <module>
#      48     R2 = range(0,14,2)
#      49     for j in R2:
# ---> 50         S += CovidStats[i][c]
#      51         print(S)
#      52 print("Overall Number of Infections: " + str(S))
#
# IndexError: tuple index out of range

# %%
# extract data
RW = range(0,13) # 13 weeks
RD = range(0,7) # 7 days per week

# Find the following:
# 1. The overall number of infections registered in the given period
# 2. The weekly number of infections per every week provided
# 3. The list of days when the number of infected people exceeded (>) 2000
# 4. The weekly percentage increment of infections (apart from week 1)
# 5. The week with the highest number of infections

OverallInfections = 0 # total sum
WeeklyInfections = [] # weekly sum
Weeks = [] # list of week
DaysAbove2000 = [] # list of days
WeekPercentIncrement = 0
MaxInfectionWeek = 0 # assume inital week to be the case

# traverse all data, sequentially, and subdivide them into weekly batches
c = 0
for week in RW:
    # examine one week
    Weeks += [week]
    WeeklySum = 0 # initialise daily average
    for day in RD:
        # extract data from files starting at c=0 for the first line
        T = int(t[c].rstrip())
        # add this temperature to the daily sum
        Sum += T
        # check if current T is higher than max or lower than min. Only one MaxT/MinT value for overall days period.
        if T > MaxT:
            MaxT = T
        if T < MinT:
            MinT = T
        # prepare to go into next data  
        c += 1 
    # tabluate total for this week and add it into the list
    WeeklyInfections += [WeeklySum]

# %%
# for reference/copying

# Read file & process data question

# read the file - standard programming lines
f = open('FTSE100.txt','r')
t = f.readlines() # save data initially into a temporary variable t
f.close()

# no of companies - set the range based on size of array that needs to be created
N = 100
RN = range(0,N)

# organise data in a list of tuples - import data from file into a list
FTSE = [] # list of companies - data type: list of tuples
c = 0
for i in RN:
    FTSE += [( t[c].rstrip() , float(t[c+1].rstrip()) , int(t[c+2].rstrip()) )] # name, share price and number of shares
    c += 3
#

#print(type(FTSE))
#print(type(FTSE[0]))

# sort the list in descending order by share price
for i in RN:
    Rj = range(i+1,N) # range of all the remaining lines after this current selection
    for j in Rj:
        # if the current share price is less than the next company's share price, swap them 
        # (i.e. bring the highest share price to the first entry/line
        if FTSE[i][1] < FTSE[j][1]: # swap '<' sign to '>' for ascending order (i.e. lowest share price as the first line)
            # swap these two companies - syntax for tuple swap
            (FTSE[i], FTSE[j]) = (FTSE[j], FTSE[i])
            # alternative syntax (basic)
            #temp = FTSE[i]
            #FTSE[i] = FTSE[j]
            #FTSE[j] = temp
for item in FTSE:
    print(item)
# 

# compute the overall value of the FTSE companies
S = 0 # initialise sum = 0
for i in RN:
    S += FTSE[i][1]*FTSE[i][2] # share price * no of shares
# convert in billion dollars
S = S / 1.0e9
print(S)

# %%
#for reference/copying

#Task D: Experimental analysis

# Data stored - 10 days * 24 hours = 240 measurements stored in Temperatures.txt
# Compute the average temperature for each day and plot it graphically
# Compute the maximum and minimum temperatures overall for the testing period

import matplotlib.pyplot as pl

# read the data
f = open('Temperatures.txt','r')
t = f.readlines()
f.close()
# extract data
RD = range(0,10) # 10 days
RH = range(0,24) # 24 hours

# compute daily averages and, at same time, find max and min
Av = [] # list of daily averages
days = [] # list of days
MaxT = int(t[0].rstrip()) # initialize/set max and min to first temperature value
MinT = MaxT

# traverse all data, sequentially, and subdivide them in daily batches
c = 0
for day in RD:
    # examine one day
    days += [day]
    Sum = 0 # initialise daily average
    for hour in RH:
        # extract single temperature, starting at c=0 for the first temperature measurement
        T = int(t[c].rstrip())
        # add this temperature to the daily sum
        Sum += T
        # check if current T is higher than max or lower than min. Only one MaxT/MinT value for overall days period.
        if T > MaxT:
            MaxT = T
        if T < MinT:
            MinT = T
        # prepare to go into next data  
        c += 1 # since RH is 24 hours, we will move from c=0 to c=24 (24 measurements) for each day's loop
    # compute average for this day  
    Av += [Sum/24]
    
# print / plot
print(MinT,MaxT)
pl.bar(days,Av)
