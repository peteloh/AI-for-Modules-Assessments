# %%
#CID:01713254
f=open('CV19.txt ','r')
c=f.readlines()
C=[]
for i in range(0,len(c)-1):
    C+=[c[i].rstrip()]
M=len(C)
N=int(M/15)
#N is the number of weeks
#print(C)
print(M,N)
#Now find the overall number of infections
#Organize the list into a list of tuples
Co=[]
for i in range(0,M,15):
    week=(C[i],C[i+1],C[i+2],C[i+3],C[i+4],C[i+5],C[i+6],C[i+7],C[i+8],C[i+9],C[i+10],C[i+11],C[i+12],C[i+13],C[i+14])
    Co+=[week]
for row in Co:
    print(row)
n=0
#n: total number of infection
#print(type(int(Co[0][4])))
for i in range(0,len(Co)):
    for j in range(2,15,2):
        n+=int(Co[i][j])
print(n)
nweek=[]
#number of infection per week
for i in range(0,len(Co)):
    inweek=0
    #number of infection at week i+1
    for j in range(2,15,2):
        inweek+=int(Co[i][j])
    nweek+=[inweek]
print(nweek)
# Out:
# 195 13
# ('Week 1', '2020-03-02', '3', '2020-03-03', '12', '2020-03-04', '38', '2020-03-05', '29', '2020-03-06', '49', '2020-03-07', '43', '2020-03-08', '67')
# ('Week 2', '2020-03-09', '46', '2020-03-10', '50', '2020-03-11', '87', '2020-03-12', '134', '2020-03-13', '208', '2020-03-14', '342', '2020-03-15', '251')
# ('Week 3', '2020-03-16', '152', '2020-03-17', '407', '2020-03-18', '676', '2020-03-19', '647', '2020-03-20', '706', '2020-03-21', '1035', '2020-03-22', '0')
# ('Week 4', '2020-03-23', '669', '2020-03-24', '967', '2020-03-25', '1427', '2020-03-26', '1452', '2020-03-27', '2129', '2020-03-28', '2885', '2020-03-29', '2546')
# ('Week 5', '2020-03-30', '2433', '2020-03-31', '2619', '2020-04-01', '3009', '2020-04-02', '4324', '2020-04-03', '4244', '2020-04-04', '4450', '2020-04-05', '3735')
# ('Week 6', '2020-04-06', '5903', '2020-04-07', '3802', '2020-04-08', '3634', '2020-04-09', '5491', '2020-04-10', '4344', '2020-04-11', '5195', '2020-04-12', '8719')
# ('Week 7', '2020-04-13', '5288', '2020-04-14', '4342', '2020-04-15', '5252', '2020-04-16', '4603', '2020-04-17', '4617', '2020-04-18', '5599', '2020-04-19', '5525')
# ('Week 8', '2020-04-20', '5850', '2020-04-21', '4676', '2020-04-22', '4301', '2020-04-23', '4451', '2020-04-24', '4583', '2020-04-25', '5386', '2020-04-26', '4913')
# ('Week 9', '2020-04-27', '4463', '2020-04-28', '4309', '2020-04-29', '3996', '2020-04-30', '4076', '2020-05-01', '6032', '2020-05-02', '6201', '2020-05-03', '4806')
# ('Week 10', '2020-05-04', '4339', '2020-05-05', '3985', '2020-05-06', '4406', '2020-05-07', '6211', '2020-05-08', '5514', '2020-05-09', '4649', '2020-05-10', '3896')
# ('Week 11', '2020-05-11', '3923', '2020-05-12', '3877', '2020-05-13', '3403', '2020-05-14', '3242', '2020-05-15', '3446', '2020-05-16', '3560', '2020-05-17', '3450')
# ('Week 12', '2020-05-18', '3534', '2020-05-19', '2711', '2020-05-20', '2412', '2020-05-21', '0', '2020-05-22', '2615', '2020-05-23', '3287', '2020-05-24', '2959')
# ('Week 13', '2020-05-25', '2405', '2020-05-26', '1625', '2020-05-27', '4043', '2020-05-28', '2013', '2020-05-29', '1887', '2020-05-30', '2095', '2020-05-31', '1604')
# 273319
# [241, 1118, 3623, 12075, 24814, 37088, 35226, 34160, 33883, 33000, 24901, 17518, 15672]
