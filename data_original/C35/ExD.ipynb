# %%
#CID:01713254
def Factorial(n):
    # this function computes the factorial of n
    Rf = range(1,n+1)
    f = 1
    for i in Rf:
        f = f * i
    return f
def S(a,N):
    if N==1:
        s=1
    else:
        s=S(a,N-1)*(((N-1)**2/N)**a)*(N-1)/f(N-2)
    return s
a=2
N=15
S(a,N)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-164a3e0c4bd8> in <module>
#      15 a=2
#      16 N=15
# ---> 17 S(a,N)
#      18
#
# <ipython-input-3-164a3e0c4bd8> in S(a, N)
#      11         s=1
#      12     else:
# ---> 13         s=S(a,N-1)*(((i-1)**2/i)**a)*(i-1)/f(i-2)
#      14     return s
#      15 a=2
#
# <ipython-input-3-164a3e0c4bd8> in S(a, N)
#      11         s=1
#      12     else:
# ---> 13         s=S(a,N-1)*(((i-1)**2/i)**a)*(i-1)/f(i-2)
#      14     return s
#      15 a=2
#
# <ipython-input-3-164a3e0c4bd8> in S(a, N)
#      11         s=1
#      12     else:
# ---> 13         s=S(a,N-1)*(((i-1)**2/i)**a)*(i-1)/f(i-2)
#      14     return s
#      15 a=2
#
# <ipython-input-3-164a3e0c4bd8> in S(a, N)
#      11         s=1
#      12     else:
# ---> 13         s=S(a,N-1)*(((i-1)**2/i)**a)*(i-1)/f(i-2)
#      14     return s
#      15 a=2
#
# ...
